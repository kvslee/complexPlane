# %%
import cplane_julia
cplane_julia.JuliaPlane(0).show()

# %%
cplane_julia.JuliaPlane(-1).show()

# %%
cplane_julia.JuliaPlane(0.3).show()

# %%
cplane_julia.JuliaPlane(-1.037 + 0.17j).show()

# %%
cplane_julia.JuliaPlane(-0.624 + 0.435j).show()

# %%
cplane_julia.JuliaPlane(-0.8 + 0.2j).show()

# %%
cplane_julia.JuliaPlane(-0.835 - 0.2321j).show()

# %%
cplane_julia.JuliaPlane(1+1j).show()

# %%
cplane_julia.JuliaPlane(1-1j).show()

# %%
cplane_julia.JuliaPlane(-1+1j).show()

# %%
cplane_julia.JuliaPlane(-1-1j).show()

# %% [markdown]
# ### Comments
# The plane changes based on different inputs of complex numbers. There are definitely patterns, even though it is hard to explain them. With some tests(1+1j, 1-1j, -1+1j, -1-1j), we could see that the shapes of patterns are flipped while keeping patterns. Very interesting and artistic! We see the beauty of numbers.
